# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrey-tspmo/DAV_4NI25CS183_github/blob/main/DAV_lab_session_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
data={"Student":["Asha","Bharat","Chitra","Deepak","Esha","Farhan",
                 "Gowri","Harish","Isha","Jatin","Kavya","Lokesh",
                 "Meera","Nikhil","Pooja","Rahul","Sneha","Tarun","Uma","Varun"],
      "Department":["CSE","AIML","CSE","ISE","AIML","CSE","ISE"
      ,"CSE","AIML","ISE","CSE","AIML",
                    "ISE","CSE","AIML","ISE","CSE","AIML","ISE","CSE"],
      "Attendance":[92,78,85,96,88,72,91,65,87,82,94,76,89,97,84,69,93,80,86,90],
      "Study_Hours":[3.5,2,3,5,4,1.5,4.5,1,3.5,2.5,5.5,2,4,6,3,1.5,5,2.5,3.5,4.5],
      "Assignment_Score":[82,68,78,94,86,62,90,55,84,73,96,70,88,98,79,60,93,74,85,91],
      "Internal_Marks":[84,70,80,95,87,65,91,58,85,75,97,72,89,99,81,63,94,76,86,92],
      "Final_Score":[86,72,82,96,88,66,93,60,86,77,98,73,90,99,83,64,95,78,87,94]}
df=pd.DataFrame(data)
display(df.head())
print("Shape:",df.shape)
print(df.dtypes)
# Out:
#   Student Department  Attendance  Study_Hours  Assignment_Score  \
# 0    Asha        CSE          92          3.5                82
# 1  Bharat       AIML          78          2.0                68
# 2  Chitra        CSE          85          3.0                78
# 3  Deepak        ISE          96          5.0                94
# 4    Esha       AIML          88          4.0                86
#
#    Internal_Marks  Final_Score
# 0              84           86
# 1              70           72
# 2              80           82
# 3              95           96
# 4              87           88
# Shape: (20, 7)
# Student              object
# Department           object
# Attendance            int64
# Study_Hours         float64
# Assignment_Score      int64
# Internal_Marks        int64
# Final_Score           int64
# dtype: object

# %%
#Histogram
plt.figure(figsize=(8,5))
plt.hist(df["Final_Score"],bins=6,edgecolor="black")
plt.xlabel("Final Score")
plt.ylabel("No. of students")
plt.title("Distribution of Final Scores")
plt.show()

# %%
#Boxplot
plt.figure(figsize=(8,5))
sns.boxplot(x="Department",y="Final_Score",data=df)
plt.xlabel("Department")
plt.ylabel("Final Score")
plt.title("Box plot of final scores")
plt.show()
#

# %%
#linear regression
plt.figure(figsize=(8,5))
plt.scatter(df["Study_Hours"],df["Final_Score"])
plt.title("Study Hours vs Final Score");plt.xlabel("Study Hours");plt.ylabel("Final Score")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data = df, x= "Study_hours",y = "Final_Score",hue="Department",s = 80)
plt.title("Study Hours vs Final Score")
plt.show()

# %%
num_cols = ["Attendance","Study_Hours","Assignment_Score","Internal_Marks","Final_Score"]
sns.pairplot(df[num_cols])
plt.show()

# %%
#Corelation matrix
corr = df[num_cols].corr()
display(corr)
# Out:
#                   Attendance  Study_Hours  Assignment_Score  Internal_Marks  \
# Attendance          1.000000     0.951301          0.975031        0.976698
# Study_Hours         0.951301     1.000000          0.981012        0.982993
# Assignment_Score    0.975031     0.981012          1.000000        0.999747
# Internal_Marks      0.976698     0.982993          0.999747        1.000000
# Final_Score         0.979425     0.978371          0.998583        0.998847
#
#                   Final_Score
# Attendance           0.979425
# Study_Hours          0.978371
# Assignment_Score     0.998583
# Internal_Marks       0.998847
# Final_Score          1.000000

# %%
plt.figure(figsize=(9,6))
sns.heatmap(corr,annot=True,fmt=".2f",cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
#Histogram of Attendance
plt.figure(figsize=(8,5))
plt.hist(df["Attendance"],bins=6,edgecolor="black")
plt.xlabel("Attendance")
plt.ylabel("No. of students")
plt.title("Distribution of Attendance")
plt.show()
#Box plot of Study_hours
plt.figure(figsize=(8,5))
sns.boxplot(x="Department",y="Study_Hours",data=df)
plt.xlabel("Department")
plt.ylabel("Study Hours")
plt.title("Box plot of Study Hours")
plt.show()

# %%
#Question:

movie_data={"Movie":["Sky Force","Code Red","Midnight Run","Ocean Echo","City Lights","Last Game","Silent Road","Future World","Hidden Truth","Wild Journey","Digital Dreams","Final Mission"],"Budget_Crore":[80,120,60,45,35,70,50,150,40,90,110,130],"Duration_Minutes":[145,160,125,135,110,150,130,170,120,155,165,158],"Rating":[8.2,7.5,8,7.8,6.9,8.5,7.6,7.2,8.1,7.9,7.4,8.3],"Revenue_Crore":[240,280,150,110,75,260,130,310,140,220,290,350]}
movies=pd.DataFrame(movie_data)
movies
# Out:
#              Movie  Budget_Crore  Duration_Minutes  Rating  Revenue_Crore
# 0        Sky Force            80               145     8.2            240
# 1         Code Red           120               160     7.5            280
# 2     Midnight Run            60               125     8.0            150
# 3       Ocean Echo            45               135     7.8            110
# 4      City Lights            35               110     6.9             75
# 5        Last Game            70               150     8.5            260
# 6      Silent Road            50               130     7.6            130
# 7     Future World           150               170     7.2            310
# 8     Hidden Truth            40               120     8.1            140
# 9     Wild Journey            90               155     7.9            220
# 10  Digital Dreams           110               165     7.4            290
# 11   Final Mission           130               158     8.3            350

# %%
#Histogram
plt.figure(figsize=(8,5))
plt.hist(movies["Rating"], bins=5, edgecolor="black")
plt.xlabel("Rating")
plt.ylabel("Number of Movies")
plt.title("Distribution of Movie Ratings")
plt.show()

# %%
#Box plot
plt.figure(figsize=(8,5))
sns.boxplot(x=movies["Budget_Crore"])
plt.xlabel("Budget (Crore)")
plt.title("Box plot of Movie Budgets")
plt.show()

# %%
#Scartter plot
plt.figure(figsize=(8,5))
sns.scatterplot(x=movies["Budget_Crore"], y=movies["Revenue_Crore"], data=movies)
plt.title("Movie Budget vs. Revenue")
plt.xlabel("Budget (Crore)")
plt.ylabel("Revenue (Crore)")
plt.show()

# %%
#pair plot for numerical columns
# Identify numerical columns in the movies DataFrame
movies_num_cols = movies.select_dtypes(include=['number']).columns.tolist()

# Create a pair plot
sns.pairplot(movies[movies_num_cols])
plt.suptitle("Pair Plot of Numerical Movie Features", y=1.02) # Add a title above the plots
plt.show()

# %%
#Correlation heatmap
#Write 3 data - driven observations
