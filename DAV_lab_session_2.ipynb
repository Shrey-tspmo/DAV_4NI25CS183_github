# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrey-tspmo/DAV_4NI25CS183_github/blob/main/DAV_lab_session_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exploratory Data Analysis (EDA)
import pandas as pd
import numpy as np

# %%
data = {'Name':["Amit","Bebo","Chetan","Amit","Divya","Ravi"],
        'Age':[25,np.nan,30,25,28,22],                                             # where np.nan represents missing values (nan = not a number)
        'Marks':[85,90,np.nan,75,95,80],
        'City':['Mysuru','Mysuru','Bengaluru','Mysuru',np.nan,'Delhi']}
df = pd.DataFrame(data)

print("Dataset:")
print(df)
# Out:
# Dataset:
#      Name   Age  Marks       City
# 0    Amit  25.0   85.0     Mysuru
# 1    Bebo   NaN   90.0     Mysuru
# 2  Chetan  30.0    NaN  Bengaluru
# 3    Amit  25.0   75.0     Mysuru
# 4   Divya  28.0   95.0        NaN
# 5    Ravi  22.0   80.0      Delhi

# %%
# Step 2: Basic information
print("\nShape of database (rows,columns):",df.shape)
print("\nColumn names:",df.columns.tolist())

print("\nData Type of each column:")
print(df.dtypes)

print("\nDataset info:")
df.info()
# Out:
# Shape of database (rows,columns): (6, 4)
#
# Column names: ['Name', 'Age', 'Marks', 'City']
#
# Data Type of each column:
# Name      object
# Age      float64
# Marks    float64
# City      object
# dtype: object
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     5 non-null      float64
#  2   Marks   5 non-null      float64
#  3   City    5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
#step 3: Descripitive  stastics
print("\nDiscriptive statisctics (numerical columns):")
print(df.describe())

print("\nMean\n",df.mean(numeric_only=True))
print("\nMedian\n",df.median(numeric_only=True))
print("\nMode\n",df.mode(numeric_only=True))
print("\nStandard Deviation\n",df.std(numeric_only=True))
# Out:
# Discriptive statisctics (numerical columns):
#              Age      Marks
# count   5.000000   5.000000
# mean   26.000000  85.000000
# std     3.082207   7.905694
# min    22.000000  75.000000
# 25%    25.000000  80.000000
# 50%    25.000000  85.000000
# 75%    28.000000  90.000000
# max    30.000000  95.000000
#
# Mean
#  Age      26.0
# Marks    85.0
# dtype: float64
#
# Median
#  Age      25.0
# Marks    85.0
# dtype: float64
#
# Mode
#      Age  Marks
# 0  25.0   75.0
# 1   NaN   80.0
# 2   NaN   85.0
# 3   NaN   90.0
# 4   NaN   95.0
#
# Standard Deviation
#  Age      3.082207
# Marks    7.905694
# dtype: float64

# %%
#step 4:
print("\nMissing values in each columns:")
print(df.isnull().sum())

print("\nTotal missing values in dataset:", df.isnull().sum().sum())
# Out:
# Missing values in each columns:
# Name     0
# Age      1
# Marks    1
# City     1
# dtype: int64
#
# Total missing values in dataset: 3

# %%
#step 5:
print("\nDuplicate rows in dataset:")
print(df[df.duplicated()])

print("\nTotal duplicate rows in dataset:",df.duplicated().sum())
print("\nEDA process completed successfully!")
# Out:
# Duplicate rows in dataset:
# Empty DataFrame
# Columns: [Name, Age, Marks, City]
# Index: []
#
# Total duplicate rows in dataset: 0
#
# EDA process completed successfully!
